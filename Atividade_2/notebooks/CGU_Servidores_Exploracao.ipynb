# %%
import pandas as pd
import numpy as np


file_path = '../data/servidorPorOrgao.csv' 
df = pd.read_csv(file_path, delimiter=';')


df_limpo = df.drop(columns=['Unnamed: 5'])

print("--- VISÃO GERAL ---")

print(f"Amostras (linhas): {df_limpo.shape[0]}")

print(f"Atributos (colunas): {df_limpo.shape[1]}") 


print("\n--- PRIMEIRAS 5 LINHAS (DF LIMPO) ---")
display(df_limpo.head())


print("\n--- TIPOS DE DADOS E VALORES NÃO-NULOS ---")
df_limpo.info()


print("\n--- VALORES FALTANTES (DF LIMPO) ---")
print(df_limpo.isnull().sum())
# Out:
# --- VISÃO GERAL ---
# Amostras (linhas): 327
# Atributos (colunas): 5
#
# --- PRIMEIRAS 5 LINHAS (DF LIMPO) ---
#   Órgão Superior Lotação                             Órgão Lotação  \
# 0         Sem informação          Tribunal Regional Eleitoral - PI
# 1         Sem informação  Prefeitura Municipal de Porto Velho - RO
# 2         Sem informação          Ministério da Previdência Social
# 3         Sem informação      MINISTERIO DO TRABALHO E PREVIDENCIA
# 4         Sem informação                      Ministério da Defesa
#
#    Servidores  Inativos  Pensionistas
# 0           1         0             0
# 1           1         0             0
# 2           1         0             0
# 3           1         0             0
# 4           1         0             0
# --- TIPOS DE DADOS E VALORES NÃO-NULOS ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Órgão Superior Lotação  327 non-null    object
#  1   Órgão Lotação           327 non-null    object
#  2   Servidores              327 non-null    int64
#  3   Inativos                327 non-null    int64
#  4   Pensionistas            327 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 12.9+ KB
#
# --- VALORES FALTANTES (DF LIMPO) ---
# Órgão Superior Lotação    0
# Órgão Lotação             0
# Servidores                0
# Inativos                  0
# Pensionistas              0
# dtype: int64
