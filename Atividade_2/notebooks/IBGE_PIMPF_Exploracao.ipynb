# %%
import pandas as pd

# %%
file_path = '../data/PIMPF - Produção física industrial por seções e atividades industriais.xlsx'

try:
    df = pd.read_excel(file_path)
    print("Dados carregados com sucesso!")
    display(df.head(15)) 

except Exception as e:
    print(f"ERRO ao carregar o arquivo: {e}")
# Out:
# Dados carregados com sucesso!
#    PIMPF - Produção física industrial por seções e atividades industriais  \
# 0                                Brasil - agosto 2025
# 1                     Seções e atividades industriais
# 2                                                 NaN
# 3                                 1 - Indústria geral
# 4                           2 - Indústrias extrativas
# 5                     3 - Indústrias de transformação
# 6          3.10 - Fabricação de produtos alimentícios
# 7                        3.11 - Fabricação de bebidas
# 8               3.12 - Fabricação de produtos do fumo
# 9               3.13 - Fabricação de produtos têxteis
# 10  3.14 - Confecção de artigos do vestuário e ace...
# 11  3.15 - Preparação de couros e fabricação de ar...
# 12           3.16 - Fabricação de produtos de madeira
# 13  3.17 - Fabricação de celulose, papel e produto...
# 14         3.18 - Impressão e reprodução de gravações
#
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                      Tipo de índice
# 2   Índice de base fixa mensal sem ajuste sazonal ...
# 3                                           113.08651
# 4                                           122.15066
# 5                                           111.54126
# 6                                           119.32308
# 7                                            94.30083
# 8                                           141.93711
# 9                                           124.30221
# 10                                          104.02092
# 11                                          106.43997
# 12                                           90.43898
# 13                                          105.63491
# 14                                          121.97354
#
#                                            Unnamed: 2  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Índice de base fixa mensal com ajuste sazonal ...
# 3                                           104.74356
# 4                                           113.97138
# 5                                            102.7812
# 6                                           106.26186
# 7                                            98.96782
# 8                                           120.30923
# 9                                           118.34932
# 10                                           97.97402
# 11                                           97.67571
# 12                                           86.37526
# 13                                          102.73916
# 14                                           114.0371
#
#                                            Unnamed: 3  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Variação percentual mês/mês imediatamente ante...
# 3                                                 0.8
# 4                                                -0.3
# 5                                                 0.6
# 6                                                 1.3
# 7                                                 1.7
# 8                                                   6
# 9                                                 0.7
# 10                                                1.3
# 11                                               -3.6
# 12                                               -8.6
# 13                                                0.7
# 14                                               26.8
#
#                                            Unnamed: 4  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Variação percentual mensal (Base: igual mês do...
# 3                                                -0.7
# 4                                                 4.8
# 5                                                -1.6
# 6                                                 0.6
# 7                                                -4.9
# 8                                                30.9
# 9                                                 7.2
# 10                                               -2.9
# 11                                               -9.6
# 12                                              -18.4
# 13                                                5.2
# 14                                               15.6
#
#                                            Unnamed: 5  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Variação percentual acumulada no ano (Base: ig...
# 3                                                 0.9
# 4                                                 3.9
# 5                                                 0.3
# 6                                                -0.4
# 7                                                -2.8
# 8                                                 7.7
# 9                                                10.7
# 10                                                0.9
# 11                                               -2.4
# 12                                               -4.3
# 13                                               -0.3
# 14                                                 -9
#
#                                            Unnamed: 6
# 0                                                 NaN
# 1                                                 NaN
# 2   Variação percentual acumulada nos últimos 12 m...
# 3                                                 1.6
# 4                                                 1.1
# 5                                                 1.7
# 6                                                -0.8
# 7                                                -3.2
# 8                                                   8
# 9                                                 9.3
# 10                                                3.5
# 11                                                 -1
# 12                                               -0.4
# 13                                                0.2
# 14                                               -5.3

# %%
print("Dimensões do Conjunto de Dados:")

print(f"Amostras (linhas): {df.shape[0]}")

print(f"Atributos (colunas): {df.shape[1]}")

print("\nTipos de Dados e Contagem de Valores Não-Nulos:")

df.info()
# Out:
# Dimensões do Conjunto de Dados:
# Amostras (linhas): 31
# Atributos (colunas): 7
#
# Tipos de Dados e Contagem de Valores Não-Nulos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   PIMPF - Produção física industrial por seções e atividades industriais  30 non-null     object
#  1   Unnamed: 1                                                              29 non-null     object
#  2   Unnamed: 2                                                              28 non-null     object
#  3   Unnamed: 3                                                              28 non-null     object
#  4   Unnamed: 4                                                              28 non-null     object
#  5   Unnamed: 5                                                              28 non-null     object
#  6   Unnamed: 6                                                              28 non-null     object
# dtypes: object(7)
# memory usage: 1.8+ KB

# %%
print("\nContagem de Valores Faltantes (NaN):")

print(df.isnull().sum())
# Out:
# Contagem de Valores Faltantes (NaN):
# PIMPF - Produção física industrial por seções e atividades industriais    1
# Unnamed: 1                                                                2
# Unnamed: 2                                                                3
# Unnamed: 3                                                                3
# Unnamed: 4                                                                3
# Unnamed: 5                                                                3
# Unnamed: 6                                                                3
# dtype: int64
